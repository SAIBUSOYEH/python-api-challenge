# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from citipy import citipy

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls

# %%
from config import api_key

# %%
# Starting URL for Weather Map API Call 
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# City not found. Skipping...
# Processing Record 1 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5&q=kaitangata
# Processing Record 2 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5&q=hermanus
# Processing Record 3 | Alausi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5&q=alausi
# Processing Record 4 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5&q=tiksi
# Processing Record 5 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5&q=puerto ayora
# Processing Record 6 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=60d7b29002415654b126178e48b80cc5&q=new norfolk
# ...

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.count()
# Out:
# City          571
# Cloudiness    571
# Country       571
# Date          571
# Humidity      571
# Lat           571
# Lng           571
# Max Temp      571
# Wind Speed    571
# dtype: int64

# %%
# Save data frame to CSV
weather_data.to_csv('../Weather_Data/weather_data.csv')

# Display data frame head 
weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    Kaitangata          58      NZ  1580869642        43 -46.28  169.85
# 1      Hermanus           1      ZA  1580869643        89 -34.42   19.23
# 2        Alausi         100      EC  1580869644        97  -2.20  -78.83
# 3         Tiksi          94      RU  1580869645        91  71.69  128.87
# 4  Puerto Ayora          87      EC  1580869646         3  -0.74  -90.35
#
#    Max Temp  Wind Speed
# 0     64.99       13.00
# 1     66.99       16.51
# 2     57.52        1.41
# 3    -27.11        3.98
# 4     79.00        3.00

# %% [markdown]
# ### Plotting the Data

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=100)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../Images/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# The temperature is an inverse proportionality of the latitude.Temperature becomes significantly warmer as one approaches the equator.
#
# Regions which experiences increase in temperature are more closer to the equator compare to regions, which experiences a lower temperature.
#
# The southern hemisphere tends to be warmer in the fall when compared to the northern hemisphere. This may be due to the tilting nature of the earth.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=100)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../Images/Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# Humidity appears to be radomly distributed across latitudes. Its fairly higher with with a low humidity values near the equator and Arctic. This is due to the humidity of tropical climates, and the northern latitudes being on the boundary between winter and spring.
#
# Absolute humidity is the total measure of water in the atmosphere (not percentage of saturation). As you get higher in altitude, the atmosphere becomes thinner (less pressure). This means that the total amount of water vapor the atmosphere can potentially hold decreases.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=100)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../Images/Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# Cloudiness is suppressed at the equator mainly due to equatorial ocean upwelling, hence atmospheric subsidence.
#
# Continents tend to be less cloudy than adjacent oceans (at the same latitude), except in the equatorial belt. On average, cloudiness is highest around 60 S (about 80% of the time) but there is only 40% cloud cover at the South Pole. At latitudes above 50 N, the annual average cloud cover is about 70%.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=100)
# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("../Images/Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# Windspeed from the graph decreases when closer to the equator.
#
# Seasonal temperature changes and the Earth’s rotation also affect wind speed and direction. Centripetal force increases air speed and influences the direction of wind flowing around the center of the circulation.
